# %%
import numpy as np
import pandas as pd
import seaborn as sns 
import matplotlib.pyplot as plt

# %%
#read data
retail_data1=pd.read_csv('Features data set.csv')
retail_data1
# Out:
#       Store        Date  Temperature  Fuel_Price  MarkDown1  MarkDown2  \
# 0         1  05/02/2010        42.31       2.572        NaN        NaN
# 1         1  12/02/2010        38.51       2.548        NaN        NaN
# 2         1  19/02/2010        39.93       2.514        NaN        NaN
# 3         1  26/02/2010        46.63       2.561        NaN        NaN
# 4         1  05/03/2010        46.50       2.625        NaN        NaN
# ...     ...         ...          ...         ...        ...        ...
# 8185     45  28/06/2013        76.05       3.639    4842.29     975.03
# 8186     45  05/07/2013        77.50       3.614    9090.48    2268.58
# 8187     45  12/07/2013        79.37       3.614    3789.94    1827.31
# 8188     45  19/07/2013        82.84       3.737    2961.49    1047.07
# 8189     45  26/07/2013        76.06       3.804     212.02     851.73
#
#       MarkDown3  MarkDown4  MarkDown5         CPI  Unemployment  IsHoliday
# ...

# %%
#read data
retail_data2=pd.read_csv('sales data-set.csv')
retail_data2
# Out:
#         Store  Dept        Date  Weekly_Sales  IsHoliday
# 0           1     1  05/02/2010      24924.50      False
# 1           1     1  12/02/2010      46039.49       True
# 2           1     1  19/02/2010      41595.55      False
# 3           1     1  26/02/2010      19403.54      False
# 4           1     1  05/03/2010      21827.90      False
# ...       ...   ...         ...           ...        ...
# 421565     45    98  28/09/2012        508.37      False
# 421566     45    98  05/10/2012        628.10      False
# 421567     45    98  12/10/2012       1061.02      False
# 421568     45    98  19/10/2012        760.01      False
# 421569     45    98  26/10/2012       1076.80      False
#
# [421570 rows x 5 columns]

# %%
#read data
retail_data3=pd.read_csv('stores data-set.csv')
retail_data3
# Out:
#     Store Type    Size
# 0       1    A  151315
# 1       2    A  202307
# 2       3    B   37392
# 3       4    A  205863
# 4       5    B   34875
# 5       6    A  202505
# 6       7    B   70713
# 7       8    A  155078
# 8       9    B  125833
# 9      10    B  126512
# 10     11    A  207499
# 11     12    B  112238
# 12     13    A  219622
# 13     14    A  200898
# 14     15    B  123737
# 15     16    B   57197
# 16     17    B   93188
# 17     18    B  120653
# 18     19    A  203819
# 19     20    A  203742
# 20     21    B  140167
# 21     22    B  119557
# 22     23    B  114533
# 23     24    A  203819
# 24     25    B  128107
# 25     26    A  152513
# 26     27    A  204184
# 27     28    A  206302
# 28     29    B   93638
# 29     30    C   42988
# 30     31    A  203750
# 31     32    A  203007
# 32     33    A   39690
# 33     34    A  158114
# 34     35    B  103681
# 35     36    A   39910
# 36     37    C   39910
# 37     38    C   39690
# 38     39    A  184109
# ...

# %%
print('feature data:' , retail_data1.shape)
print('sales data :' ,retail_data2.shape)
print('stores data:' ,retail_data3.shape)
# Out:
# feature data: (8190, 12)
# sales data : (421570, 5)
# stores data: (45, 3)

# %%
df=pd.merge(retail_data2,retail_data1, on=['Store','Date', 'IsHoliday'], how='left')
df=pd.merge(df,retail_data3, on=['Store'], how='left')

# %%
df.head()
# Out:
#    Store  Dept        Date  Weekly_Sales  IsHoliday  Temperature  Fuel_Price  \
# 0      1     1  05/02/2010      24924.50      False        42.31       2.572
# 1      1     1  12/02/2010      46039.49       True        38.51       2.548
# 2      1     1  19/02/2010      41595.55      False        39.93       2.514
# 3      1     1  26/02/2010      19403.54      False        46.63       2.561
# 4      1     1  05/03/2010      21827.90      False        46.50       2.625
#
#    MarkDown1  MarkDown2  MarkDown3  MarkDown4  MarkDown5         CPI  \
# 0        NaN        NaN        NaN        NaN        NaN  211.096358
# 1        NaN        NaN        NaN        NaN        NaN  211.242170
# 2        NaN        NaN        NaN        NaN        NaN  211.289143
# 3        NaN        NaN        NaN        NaN        NaN  211.319643
# 4        NaN        NaN        NaN        NaN        NaN  211.350143
#
#    Unemployment Type    Size
# 0         8.106    A  151315
# ...

# %%
df.shape
# Out:
# (421570, 16)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 421570 entries, 0 to 421569
# Data columns (total 16 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   Store         421570 non-null  int64
#  1   Dept          421570 non-null  int64
#  2   Date          421570 non-null  object
#  3   Weekly_Sales  421570 non-null  float64
#  4   IsHoliday     421570 non-null  bool
#  5   Temperature   421570 non-null  float64
#  6   Fuel_Price    421570 non-null  float64
#  7   MarkDown1     150681 non-null  float64
#  8   MarkDown2     111248 non-null  float64
#  9   MarkDown3     137091 non-null  float64
#  10  MarkDown4     134967 non-null  float64
#  11  MarkDown5     151432 non-null  float64
#  12  CPI           421570 non-null  float64
#  13  Unemployment  421570 non-null  float64
#  14  Type          421570 non-null  object
#  15  Size          421570 non-null  int64
# dtypes: bool(1), float64(10), int64(3), object(2)
# ...

# %% [markdown]
# # Cleaning data

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# MarkDown2       310322
# MarkDown4       286603
# MarkDown3       284479
# MarkDown1       270889
# MarkDown5       270138
# Store                0
# Dept                 0
# Date                 0
# Weekly_Sales         0
# IsHoliday            0
# Temperature          0
# Fuel_Price           0
# CPI                  0
# Unemployment         0
# Type                 0
# Size                 0
# dtype: int64

# %%
df["MarkDown1"].fillna("0", inplace = True)
df["MarkDown2"].fillna("0", inplace = True)
df["MarkDown3"].fillna("0", inplace = True)
df["MarkDown4"].fillna("0", inplace = True)
df["MarkDown5"].fillna("0", inplace = True)

# %%
df.isnull().sum().sort_values(ascending = False)
# Out:
# Store           0
# Dept            0
# Date            0
# Weekly_Sales    0
# IsHoliday       0
# Temperature     0
# Fuel_Price      0
# MarkDown1       0
# MarkDown2       0
# MarkDown3       0
# MarkDown4       0
# MarkDown5       0
# CPI             0
# Unemployment    0
# Type            0
# Size            0
# dtype: int64

# %% [markdown]
# # Retails EDA

# %%
df.describe(include='all')
# Out:
#                 Store           Dept        Date   Weekly_Sales IsHoliday  \
# count   421570.000000  421570.000000      421570  421570.000000    421570
# unique            NaN            NaN         143            NaN         2
# top               NaN            NaN  23/12/2011            NaN     False
# freq              NaN            NaN        3027            NaN    391909
# mean        22.200546      44.260317         NaN   15981.258123       NaN
# std         12.785297      30.492054         NaN   22711.183519       NaN
# min          1.000000       1.000000         NaN   -4988.940000       NaN
# 25%         11.000000      18.000000         NaN    2079.650000       NaN
# 50%         22.000000      37.000000         NaN    7612.030000       NaN
# 75%         33.000000      74.000000         NaN   20205.852500       NaN
# max         45.000000      99.000000         NaN  693099.360000       NaN
#
#           Temperature     Fuel_Price MarkDown1 MarkDown2 MarkDown3 MarkDown4  \
# ...

# %%
df.hist(bins=20, figsize=(25,30))
plt.show()

# %%
plots = sns.barplot(data = df, x = 'IsHoliday', y = 'Fuel_Price')

# %% [markdown]
# Fuel Price is less price in holiday

# %%
plots = sns.barplot(data = df, x = 'IsHoliday', y = 'Weekly_Sales')

# %% [markdown]
# weekly sales in holiday is more than other days

# %%
plots = sns.barplot(data = df, x = 'IsHoliday', y = 'CPI')

# %%
plots = sns.lineplot(data = df, x = 'Temperature', y = 'Weekly_Sales')

# %% [markdown]
# the most weekly sales  in Temperature from 20:40

# %%
plots = sns.barplot(data = df, x = 'Type', y = 'Weekly_Sales')

# %% [markdown]
# type A in store is the most weekly sales

# %%
stores_date=df.groupby(by=['Date'] , as_index=False)['Weekly_Sales'].sum()
stores_date.sort_values(by='Weekly_Sales', ascending=False)
# Out:
#            Date  Weekly_Sales
# 112  24/12/2010   80931415.60
# 107  23/12/2011   76998241.31
# 117  25/11/2011   66593605.26
# 122  26/11/2010   65821003.24
# 79   17/12/2010   61820799.85
# ..          ...           ...
# 62   14/01/2011   40673678.04
# 95   21/01/2011   40654648.03
# 142  31/12/2010   40432519.00
# 123  27/01/2012   39834974.67
# 128  28/01/2011   39599852.99
#
# [143 rows x 2 columns]

# %% [markdown]
# most weekly sales was in date 24/12/2010

# %%
best_stores_type=df.groupby(by=['Type'] , as_index=False)['Weekly_Sales'].sum()
best_stores_type.sort_values(by='Weekly_Sales', ascending=False)
# Out:
#   Type  Weekly_Sales
# 0    A  4.331015e+09
# 1    B  2.000701e+09
# 2    C  4.055035e+08

# %% [markdown]
# best weekly sales is from store of type A

# %%
best_stores_sales=df.groupby(by=['Store'] , as_index=False)['Weekly_Sales'].sum()
best_stores_sales.sort_values(by='Weekly_Sales', ascending=False)
# Out:
#     Store  Weekly_Sales
# 19     20  3.013978e+08
# 3       4  2.995440e+08
# 13     14  2.889999e+08
# 12     13  2.865177e+08
# 1       2  2.753824e+08
# 9      10  2.716177e+08
# 26     27  2.538559e+08
# 5       6  2.237561e+08
# 0       1  2.224028e+08
# 38     39  2.074455e+08
# 18     19  2.066349e+08
# 30     31  1.996139e+08
# 22     23  1.987506e+08
# 23     24  1.940160e+08
# 10     11  1.939628e+08
# 27     28  1.892637e+08
# 40     41  1.813419e+08
# 31     32  1.668192e+08
# 17     18  1.551147e+08
# 21     22  1.470756e+08
# 11     12  1.442872e+08
# 25     26  1.434164e+08
# 33     34  1.382498e+08
# 39     40  1.378703e+08
# 34     35  1.315207e+08
# 7       8  1.299512e+08
# 16     17  1.277821e+08
# 44     45  1.123953e+08
# 20     21  1.081179e+08
# 24     25  1.010612e+08
# 42     43  9.056544e+07
# 14     15  8.913368e+07
# 6       7  8.159828e+07
# 41     42  7.956575e+07
# 8       9  7.778922e+07
# 28     29  7.714155e+07
# 15     16  7.425243e+07
# ...

# %% [markdown]
# the best store in weekly sales was store number 20

# %%
dataplot = sns.heatmap(df.corr(), cmap="YlGnBu", annot=True)
plt.show()

# %% [markdown]
# corroleation matrix for Retail store
